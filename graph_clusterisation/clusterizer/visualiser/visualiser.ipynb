# %%
import pandas as pd
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D


def get_cluster_column(path_to_file):
    cluster_column = []
    cluster_id = 1

    with open(path_to_file, 'r') as file:
        file.readline()

        for line in file.readlines():

            for vertex_id in line.split():
                cluster_column.append((int(vertex_id), cluster_id))

            cluster_id += 1

    cluster_column.sort(key=lambda item: item[0])

    return [row[1] for row in cluster_column]


def draw(data, path_to_cluster_column):
    cluster_column = get_cluster_column(path_to_cluster_column)

    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(data[data.h != 'm']['x'],
               data[data.h != 'm']['y'],
               data[data.h != 'm']['z'],
               c=cluster_column)
    ax.set_title(' '.join(path_to_cluster_column.split('.')[0].split('_')[1:]))
    plt.show()

# %%
# %matplotlib notebook
draw(pd.read_csv('../../../data/zonetab-mel-animal-1.csv'), './data/brain_mel_1.out')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
draw(pd.read_csv('../../../data/zonetab-mel-animal-2.csv'), './data/brain_mel_2.out')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9f14a7b5f0ee> in <module>
# ----> 1 draw(pd.read_csv('./data/zonetab-mel-animal-2.csv'), './data/brain_mel_2.out')
#
# NameError: name 'draw' is not defined

# %%
draw(pd.read_csv('../../../data/zonetab-mel-animal-3.csv'), './data/brain_mel_3.out')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2a72d5d9ce5e> in <module>
# ----> 1 draw(pd.read_csv('./data/zonetab-mel-animal-3.csv'), './data/brain_mel_3.out')
#
# NameError: name 'draw' is not defined

# %%
draw(pd.read_csv('../../../data/zonetab-sim-animal-2.csv'), './data/brain_sim_2.out')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d94683eb3790> in <module>
# ----> 1 draw(pd.read_csv('./data/zonetab-sim-animal-2.csv'), './data/brain_sim_2.out')
#
# NameError: name 'draw' is not defined

# %%
draw(pd.read_csv('../../../data/zonetab-sim-animal-3.csv'), './data/brain_sim_3.out')
# Out:
# <img src="data:image/png;base64,..." width="1151.1111416051426">

# %%
draw(pd.read_csv('../../../data/zonetab-sim-animal-4.csv'), './data/brain_sim_4.out')
# Out:
# <img src="data:image/png;base64,..." width="1151.1111416051426">
